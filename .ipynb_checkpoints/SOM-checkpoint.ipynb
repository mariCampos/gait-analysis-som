# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import sompy
import csv

# %%
# data_location = './data/01/01_Gang_08_04.csv'
# columns = ["Upper spine Accel Earth X,mG", 'Upper spine Accel Earth Y,mG', 'Upper spine Accel Earth Z,mG']
# data = pd.read_csv(data_location, engine='python', sep=';', encoding='utf-8', skiprows=[0,1])
# dataset = data.iloc[2:1824, 87:177]

# print("DATASET", dataset)

# # data = data.values

# mapsize = [20,20]
# som = sompy.SOMFactory.build(data, mapsize, mask=None, mapshape='planar', lattice='rect', normalization='var', initialization='pca', neighborhood='gaussian', training='batch', name='sompy')  # this will use the default parameters, but i can change the initialization and neighborhood methods
# som.train(n_job=1, verbose='debug', train_rough_len=500)

data_location = './data/01/01_Gang_08_04.csv'
data = pd.read_csv(data_location, engine='python')
# data = data.drop(['Number', 'Gender', 'Age'], axis=1)
print(data.head())

data = data.values
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-25-06adb7204bc2> in <module>
#      13
#      14 data_location = './data/01/01_Gang_08_04.csv'
# ---> 15 data = pd.read_csv(data_location)
#      16 # data = data.drop(['Number', 'Gender', 'Age'], axis=1)
#      17 print(data.head())
#
# ...

# %%
umat = sompy.umatrix.UMatrixView(20, 20, 'umatrix', show_axis=True, text_size=8, show_text=True)
umat.show(som)

from sompy.visualization.bmuhits import BmuHitsView
bmuhits  = BmuHitsView(20,20,"Hits Map",text_size=14)
bmuhits.show(som, anotate=True, onlyzeros=False, labelsize=12, cmap="Greys", logaritmic=False)
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-2c4577acb80c> in <module>
#       4 from sompy.visualization.bmuhits import BmuHitsView
#       5 bmuhits  = BmuHitsView(20,20,"Hits Map",text_size=14)
# ----> 6 bmuhits.show(som, anotate=True, onlyzeros=False, labelsize=12, cmap="Greys", logaritmic=False)
#
# ~/.local/lib/python3.6/site-packages/sompy/visualization/bmuhits.py in show(self, som, anotate, onlyzeros, labelsize, cmap, logaritmic)
#      19     def show(self, som, anotate=True, onlyzeros=False, labelsize=7, cmap="jet", logaritmic = False):
#      20         (self.width, self.height, indtoshow, no_row_in_plot, no_col_in_plot,
# ---> 21          axis_num) = self._calculate_figure_params(som, 1, 1)
#      22
#      23         self.prepare()
#
# ...

# %%
from sompy.visualization.hitmap import HitMapView

hits = HitMapView(20, 20,"Clustering",text_size=10, cmap=plt.cm.jet)
a = hits.show(som)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/sompy/visualization/hitmap.py in show(self, som, data)
#      16         try:
# ---> 17             codebook = getattr(som, 'cluster_labels')
#      18         except:
#
# AttributeError: 'SOM' object has no attribute 'cluster_labels'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-04b1c9aaa422> in <module>
#       2
#       3 hits = HitMapView(20, 20,"Clustering",text_size=10, cmap=plt.cm.jet)
# ----> 4 a = hits.show(som)
#       5 plt.show()
#
# ~/.local/lib/python3.6/site-packages/sompy/visualization/hitmap.py in show(self, som, data)
#      17             codebook = getattr(som, 'cluster_labels')
#      18         except:
# ---> 19             codebook = som.cluster()
# ...
