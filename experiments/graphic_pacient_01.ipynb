# %% [markdown]
# # Pacient 1 Graphic
#
# https://matplotlib.org/3.1.0/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %%
import matplotlib.pylab as plt
import matplotlib
import pandas as pd
import numpy as np
import sompy
import csv
# Out:
# Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
pacient = '02/02'
velocity = '08'

data_location = './../data/'+pacient+'_Gang_'+ velocity + '_01.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)

new_data
# Out:
#       Time,s  Lumbar Flexion,deg  Lumbar Lateral - RT,deg  \
# 0       0.00           -1.393490                 0.213378
# 1       0.01           -1.398710                 0.196020
# 2       0.02           -1.410280                 0.182254
# 3       0.03           -1.428750                 0.157415
# 4       0.04           -1.445540                 0.148736
# 5       0.05           -1.454680                 0.124795
# 6       0.06           -1.473900                 0.098160
# 7       0.07           -1.492930                 0.055963
# 8       0.08           -1.503190                 0.018854
# 9       0.09           -1.511020                -0.042197
# 10      0.10           -1.524640                -0.098459
# 11      0.11           -1.530430                -0.155320
# 12      0.12           -1.538820                -0.220261
# 13      0.13           -1.538450                -0.302560
# 14      0.14           -1.540130                -0.367800
# ...

# %%
# Get only columns
columns_names = ['Upper spine Accel Earth X,mG', 'Upper spine Accel Earth Y,mG', 'Upper spine Accel Earth Z,mG',
                 'Lower spine Accel Earth X,mG', 'Lower spine Accel Earth Y,mG', 'Lower spine Accel Earth Z,mG',
                 'LT Hand Accel Earth X,mG', 'LT Hand Accel Earth Y,mG', 'LT Hand Accel Earth Z,mG', 
                 'RT Hand Accel Earth X,mG', 'RT Hand Accel Earth Y,mG', 'RT Hand Accel Earth Z,mG', 
                 'LT Shank Accel Earth X,mG', 'LT Shank Accel Earth Y,mG', 'LT Shank Accel Earth Z,mG',
                 'RT Shank Accel Earth X,mG', 'RT Shank Accel Earth Y,mG', 'RT Shank Accel Earth Z,mG', 
                 'LT Foot Accel Earth X,mG', 'LT Foot Accel Earth Y,mG', 'LT Foot Accel Earth Z,mG', 
                 'RT Foot Accel Earth X,mG', 'RT Foot Accel Earth Y,mG', 'RT Foot Accel Earth Z,mG']

new_data = new_data.loc[500, columns_names]
new_data
# Out:
# Upper spine Accel Earth X,mG    -34.71310
# Upper spine Accel Earth Y,mG     37.70170
# Upper spine Accel Earth Z,mG    -73.34820
# Lower spine Accel Earth X,mG    -22.02640
# Lower spine Accel Earth Y,mG     24.16520
# Lower spine Accel Earth Z,mG    -63.30580
# LT Hand Accel Earth X,mG         59.53620
# LT Hand Accel Earth Y,mG        -57.25920
# LT Hand Accel Earth Z,mG       -104.43200
# RT Hand Accel Earth X,mG         23.48080
# RT Hand Accel Earth Y,mG         53.45730
# RT Hand Accel Earth Z,mG        -99.41260
# LT Shank Accel Earth X,mG      -173.13100
# LT Shank Accel Earth Y,mG        11.63700
# LT Shank Accel Earth Z,mG         3.08672
# RT Shank Accel Earth X,mG       394.08800
# RT Shank Accel Earth Y,mG      -254.05700
# RT Shank Accel Earth Z,mG        42.42570
# LT Foot Accel Earth X,mG        -31.70990
# LT Foot Accel Earth Y,mG        -26.33880
# LT Foot Accel Earth Z,mG          3.01160
# RT Foot Accel Earth X,mG        819.62500
# ...

# %%
X = (new_data[0], new_data[3], new_data[6], new_data[9])
Y = (new_data[1], new_data[4], new_data[7], new_data[10])
Z = (new_data[2], new_data[5], new_data[8], new_data[11])
ind = np.arange(4)  # the x locations for the groups
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, X, width, label='X')
rects2 = ax.bar(ind + width/2, Y, width, label='Y')
rects3 = ax.bar(ind + 1.5*(width), Z, width, label='Z')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accelerometer')
ax.set_title('Sensors')
ax.set_xticks(ind)
ax.set_xticklabels(('Upper Spine', 'Lower Spine', 'Left Hand', 'Right Hand'))
ax.legend()

fig.tight_layout()

plt.show()
# Out:
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
