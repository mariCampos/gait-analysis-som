# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import sompy
import csv
import skfuzzy as fuzz
from sklearn.cluster import KMeans

# %%
total = []

#Get data from all pacients

# pacients = ["01/01", "02/02", "03/03", "04/04", "05/05", "06/06", "07/07", "08/08"]
pacient = "01/01"

velocity = "08"

# repetitions = ["01","02", "03", "04", "05", "06", "07", "08", "09", "10"]
index = "01"

data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

# %%
index = "02"

data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "03"
data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "04"
data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "05"
data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "06"

data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "07"
data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "08"
data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "09"
data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

index = "10"
data_location = './../data/'+pacient+'_Gang_'+ velocity + '_' + index + '.csv'
read_data = pd.read_csv(data_location, engine='python', sep=None)
new_data = pd.DataFrame(read_data)
frames = []
column1 = new_data.loc[:,'Upper spine Accel Earth X,mG']
column2 = new_data.loc[:,'Upper spine Accel Earth Y,mG']
column3 = new_data.loc[:,'Upper spine Accel Earth Z,mG']
column4 = new_data.loc[:, 'RT Foot Accel Earth X,mG']
column5 = new_data.loc[:, 'RT Foot Accel Earth Y,mG']
column6 = new_data.loc[:, 'RT Foot Accel Earth Z,mG']

frames = [pd.DataFrame(column1.values), pd.DataFrame(column2.values), pd.DataFrame(column3.values),
         pd.DataFrame(column4.values), pd.DataFrame(column5.values), pd.DataFrame(column6.values)]

result = pd.concat(frames)
total.append(pd.DataFrame(result))

# %%
# concat_all = pd.concat(total, axis=1, join='inner')
# concat_all

concat_all1 = total[0].reset_index(drop=True).merge(total[1].reset_index(drop=True), left_index=True, right_index=True)
concat_all2 = concat_all1.reset_index(drop=True).merge(total[2].reset_index(drop=True), left_index=True, right_index=True)
concat_all3 = concat_all2.reset_index(drop=True).merge(total[3].reset_index(drop=True), left_index=True, right_index=True)
concat_all4 = concat_all3.reset_index(drop=True).merge(total[4].reset_index(drop=True), left_index=True, right_index=True)
concat_all5 = concat_all4.reset_index(drop=True).merge(total[5].reset_index(drop=True), left_index=True, right_index=True)
concat_all6 = concat_all5.reset_index(drop=True).merge(total[6].reset_index(drop=True), left_index=True, right_index=True)
concat_all7 = concat_all6.reset_index(drop=True).merge(total[7].reset_index(drop=True), left_index=True, right_index=True)
concat_all8 = concat_all7.reset_index(drop=True).merge(total[8].reset_index(drop=True), left_index=True, right_index=True)
concat_all = concat_all8.reset_index(drop=True).merge(total[9].reset_index(drop=True), left_index=True, right_index=True)
# Out:
#             0_x       0_y        0_x        0_y            0
# 0     12.950600  15.72380  -9.644030   2.231580     2.856960
# 1     -9.703270   4.06126 -17.420900  -2.321170     3.911230
# 2     -8.494380  15.31770  -6.868350   8.087450     1.815700
# 3     -6.867520  16.13670  -2.208870   9.887380   -10.757500
# 4     -2.610690  15.65610 -10.035800   9.911810     2.004430
# 5    -13.021300  -3.12040  -6.009810  15.849100     6.312640
# 6    -15.908500   1.52974   0.550135   6.588870    12.319400
# 7    -29.386300   1.48913  -0.966904   8.152610    15.827200
# 8    -21.271300   9.17167  -5.109590  16.663600    14.558100
# 9    -33.398800   5.61807  -7.643540  15.792100    12.436600
# 10   -36.530300  -2.99856  -2.700660   9.822230     9.937530
# 11   -27.945900 -21.30810  -3.200780  17.380300    14.460500
# 12   -22.338700 -13.82860  -4.601130  17.396600     7.562150
# 13   -29.309200 -20.94930  -3.834270  17.347700    15.234900
# 14   -22.319500 -13.88950  -0.091689   9.349850     2.056490
# 15   -20.930500  -9.70640  -2.734000  27.430600     0.559677
# 16   -10.757800 -13.64580  -1.558720  20.125000   -11.174000
# 17     2.668560 -16.10290  -8.760480  25.288600   -26.480500
# 18     0.520852  -8.57602   2.000490  21.509500   -21.007400
# 19    11.298000   1.22515   6.434910  17.412900   -16.061400
# 20     8.500810  -4.39293   3.617550  12.697200   -13.562400
# 21    25.547400  -2.73458   3.684240  16.158600    -1.900300
# 22    39.160300 -14.04520  -5.167930   9.569750    -8.551350
# 23    33.752500  -7.78407  -5.034570   7.663940   -12.371500
# 24    24.210000 -17.17910   6.826670   8.535400   -20.896800
# 25    10.519900  -9.89593   2.800690  -2.337460   -11.063400
# 26    -7.317640  -5.74668   1.775440  -2.948300   -13.627500
# 27   -21.258500  -6.13927   9.560680  -0.814447   -15.462700
# 28   -29.418500   4.04095   3.917630   2.076840    -8.349600
# 29   -37.977200   7.03951  -5.334640   8.128180    -3.637900
# ...         ...       ...        ...        ...          ...
# 7482  -5.128990  18.65210  -2.753550  -0.631590   253.365000
# 7483  -1.200400  19.68500 -11.014200  -3.315850   223.268000
# 7484   1.855170  10.69310   2.508790   9.579110   302.195000
# 7485   1.145840  54.80200  -3.487820  11.947600   296.544000
# 7486  -2.400800  44.59500  -5.017570  -1.842140   302.072000
# 7487  -7.966300  38.94470   2.937120   3.789540   324.676000
# 7488  -3.601200  42.95460  -1.223800   8.000140  1010.020000
# 7489  -7.857170  15.49280  -5.201140   0.894752  1053.200000
# 7490 -10.148800  26.36820   5.139950  -1.631610   882.938000
# 7491 -13.750100  41.80020   3.426630  -2.210560   704.508000
# 7492  -7.147840  24.60620  -1.774510   3.947440   302.195000
# 7493  -8.184560   8.87039  -0.122380  13.263400   296.544000
# 7494  -2.728190  19.07740  -0.611899   3.631640   302.072000
# 7495  -5.620060  29.10220  -4.711620  -0.894752   324.676000
# 7496   5.620060  28.06930  -7.526360   8.000140  1010.020000
# 7497   0.545637  22.11520  -1.346180  10.158100  1053.200000
# 7498  -7.147840  44.71650  -2.264030   9.368580   882.938000
# 7499  -0.054564  48.72640  -5.262330   1.052650   704.508000
# 7500  -5.456370  29.58820   3.304260   4.000070    -1.027330
# 7501  -4.365100  50.30610  -9.729200   6.263270     2.208760
# 7502  -5.892880  56.01710  -2.814740   8.105400     1.284160
# 7503  -5.183550  57.71830  -5.690660   9.473850     0.924598
# 7504   1.582350  54.68050   3.671390   9.894910    -5.701680
# 7505   1.309530  23.08730  -6.914460   6.210630    -8.064540
# 7506 -11.622100  60.69540   2.814740  12.368600    -2.876530
# 7507  -2.182550  41.49640  -3.181880  13.842300    -0.873231
# 7508   4.528790  84.93700  -2.998310   9.368580     0.667765
# 7509  -5.892880  62.39650   5.507090  10.000200    -4.982550
# 7510 -10.530800  79.71200  -1.468560   8.579100     1.489630
# 7511  -5.019860  53.58690  11.687300   8.052770    -3.492920
#
# [7512 rows x 5 columns]

# %%
def cluster(som, n_clusters=2):
    cl_labels = KMeans(n_clusters=n_clusters).fit(
        som._normalizer.denormalize_by(som.data_raw, som.codebook.matrix)
    )
    return cl_labels

# %%
data = concat_all.values
mapsize = [50,50]
som = sompy.SOMFactory.build(data, mapsize, mask=None, mapshape='planar', lattice="rect", normalization='var', initialization='pca', neighborhood='gaussian', training='batch', name='sompy')
som.train(n_job=4, verbose='debug', train_rough_len=1000)
# Out:
#  Training...
# --------------------------------------------------------------
#  details:
#       > data len is 7512 and data dimension is 5
#       > map size is 50,50
#       > array size in log10 scale is 7.972665592266111
#       > number of jobs in parallel: 4
#  -------------------------------------------------------------
#
#  pca_linear_initialization took: 0.040000 seconds
#  Rough training...
#  radius_ini: 7.000000 , radius_final: 1.750000, trainlen: 1000
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 1 ---> elapsed time:  0.508000, quantization error: 1.141387
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 2 ---> elapsed time:  0.547000, quantization error: 0.980545
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.047000 seconds
#  epoch: 3 ---> elapsed time:  0.558000, quantization error: 0.836059
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 4 ---> elapsed time:  0.532000, quantization error: 0.792708
#
#  find_bmu took: 0.306000 seconds
#  update_codebook_voronoi took: 0.046000 seconds
#  epoch: 5 ---> elapsed time:  0.523000, quantization error: 0.781383
#
#  find_bmu took: 0.306000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 6 ---> elapsed time:  0.540000, quantization error: 0.778137
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 7 ---> elapsed time:  0.503000, quantization error: 0.775914
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 8 ---> elapsed time:  0.622000, quantization error: 0.774507
#
#  find_bmu took: 0.206000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 9 ---> elapsed time:  0.412000, quantization error: 0.773508
#
#  find_bmu took: 0.313000 seconds
#  update_codebook_voronoi took: 0.058000 seconds
#  epoch: 10 ---> elapsed time:  0.571000, quantization error: 0.772403
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 11 ---> elapsed time:  0.680000, quantization error: 0.771192
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 12 ---> elapsed time:  0.514000, quantization error: 0.770144
#
#  find_bmu took: 0.414000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 13 ---> elapsed time:  0.733000, quantization error: 0.768937
#
#  find_bmu took: 0.507000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 14 ---> elapsed time:  0.828000, quantization error: 0.767764
#
#  find_bmu took: 0.510000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 15 ---> elapsed time:  0.836000, quantization error: 0.766894
#
#  find_bmu took: 0.416000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 16 ---> elapsed time:  0.744000, quantization error: 0.766014
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 17 ---> elapsed time:  0.853000, quantization error: 0.765280
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 18 ---> elapsed time:  0.620000, quantization error: 0.764513
#
#  find_bmu took: 0.321000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 19 ---> elapsed time:  0.511000, quantization error: 0.763657
#
#  find_bmu took: 0.708000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 20 ---> elapsed time:  1.020000, quantization error: 0.762842
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 21 ---> elapsed time:  0.521000, quantization error: 0.762028
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 22 ---> elapsed time:  0.509000, quantization error: 0.761422
#
#  find_bmu took: 0.306000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 23 ---> elapsed time:  0.515000, quantization error: 0.760880
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 24 ---> elapsed time:  0.530000, quantization error: 0.760293
#
#  find_bmu took: 0.306000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 25 ---> elapsed time:  0.523000, quantization error: 0.759540
#
#  find_bmu took: 0.306000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 26 ---> elapsed time:  0.511000, quantization error: 0.758937
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 27 ---> elapsed time:  0.655000, quantization error: 0.758489
#
#  find_bmu took: 0.607000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 28 ---> elapsed time:  0.806000, quantization error: 0.758165
#
#  find_bmu took: 0.507000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 29 ---> elapsed time:  0.720000, quantization error: 0.757855
#
#  find_bmu took: 0.313000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 30 ---> elapsed time:  0.525000, quantization error: 0.757378
#
#  find_bmu took: 0.410000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 31 ---> elapsed time:  0.709000, quantization error: 0.756818
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 32 ---> elapsed time:  0.672000, quantization error: 0.756591
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 33 ---> elapsed time:  0.518000, quantization error: 0.756315
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 34 ---> elapsed time:  0.706000, quantization error: 0.755966
#
#  find_bmu took: 0.514000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 35 ---> elapsed time:  0.803000, quantization error: 0.755623
#
#  find_bmu took: 0.418000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 36 ---> elapsed time:  0.695000, quantization error: 0.755406
#
#  find_bmu took: 0.206000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 37 ---> elapsed time:  0.422000, quantization error: 0.755144
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 38 ---> elapsed time:  0.569000, quantization error: 0.754770
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 39 ---> elapsed time:  0.537000, quantization error: 0.754596
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 40 ---> elapsed time:  0.594000, quantization error: 0.754297
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.047000 seconds
#  epoch: 41 ---> elapsed time:  0.538000, quantization error: 0.754042
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 42 ---> elapsed time:  0.681000, quantization error: 0.753839
#
#  find_bmu took: 0.310000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 43 ---> elapsed time:  0.514000, quantization error: 0.753545
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 44 ---> elapsed time:  0.701000, quantization error: 0.753156
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 45 ---> elapsed time:  0.701000, quantization error: 0.752857
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 46 ---> elapsed time:  0.632000, quantization error: 0.752438
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 47 ---> elapsed time:  0.628000, quantization error: 0.752131
#
#  find_bmu took: 0.307000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 48 ---> elapsed time:  0.525000, quantization error: 0.751837
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 49 ---> elapsed time:  0.640000, quantization error: 0.751480
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 50 ---> elapsed time:  0.641000, quantization error: 0.751169
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 51 ---> elapsed time:  0.648000, quantization error: 0.750820
#  find_bmu took: 0.412000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 52 ---> elapsed time:  0.643000, quantization error: 0.750493
#
#  find_bmu took: 0.413000 seconds
#  update_codebook_voronoi took: 0.039000 seconds
#  epoch: 53 ---> elapsed time:  0.659000, quantization error: 0.750118
#
#  find_bmu took: 0.506000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 54 ---> elapsed time:  0.805000, quantization error: 0.749776
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 55 ---> elapsed time:  0.599000, quantization error: 0.749436
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 56 ---> elapsed time:  0.622000, quantization error: 0.749097
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 57 ---> elapsed time:  0.649000, quantization error: 0.748734
#
#  find_bmu took: 0.421000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 58 ---> elapsed time:  0.656000, quantization error: 0.748406
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 59 ---> elapsed time:  0.626000, quantization error: 0.748090
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.038000 seconds
#  epoch: 60 ---> elapsed time:  0.738000, quantization error: 0.747754
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 61 ---> elapsed time:  0.619000, quantization error: 0.747405
#
#  find_bmu took: 0.416000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 62 ---> elapsed time:  0.724000, quantization error: 0.747096
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 63 ---> elapsed time:  0.567000, quantization error: 0.746762
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 64 ---> elapsed time:  0.626000, quantization error: 0.746369
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 65 ---> elapsed time:  0.534000, quantization error: 0.746016
#
#  find_bmu took: 0.317000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 66 ---> elapsed time:  0.543000, quantization error: 0.745705
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 67 ---> elapsed time:  0.572000, quantization error: 0.745359
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 68 ---> elapsed time:  0.667000, quantization error: 0.745004
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 69 ---> elapsed time:  0.517000, quantization error: 0.744679
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 70 ---> elapsed time:  0.645000, quantization error: 0.744303
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 71 ---> elapsed time:  0.631000, quantization error: 0.743920
#
#  find_bmu took: 0.421000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 72 ---> elapsed time:  0.650000, quantization error: 0.743514
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 73 ---> elapsed time:  0.557000, quantization error: 0.743143
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 74 ---> elapsed time:  0.643000, quantization error: 0.742765
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 75 ---> elapsed time:  0.522000, quantization error: 0.742342
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 76 ---> elapsed time:  0.648000, quantization error: 0.741978
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 77 ---> elapsed time:  0.679000, quantization error: 0.741598
#
#  find_bmu took: 0.613000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 78 ---> elapsed time:  0.840000, quantization error: 0.741207
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 79 ---> elapsed time:  0.540000, quantization error: 0.740845
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 80 ---> elapsed time:  0.749000, quantization error: 0.740478
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 81 ---> elapsed time:  0.643000, quantization error: 0.740092
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.039000 seconds
#  epoch: 82 ---> elapsed time:  0.649000, quantization error: 0.739740
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 83 ---> elapsed time:  0.695000, quantization error: 0.739368
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 84 ---> elapsed time:  0.635000, quantization error: 0.738997
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 85 ---> elapsed time:  0.558000, quantization error: 0.738611
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 86 ---> elapsed time:  0.637000, quantization error: 0.738218
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 87 ---> elapsed time:  0.632000, quantization error: 0.737863
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 88 ---> elapsed time:  0.760000, quantization error: 0.737470
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 89 ---> elapsed time:  0.628000, quantization error: 0.737077
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 90 ---> elapsed time:  0.667000, quantization error: 0.736699
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 91 ---> elapsed time:  0.547000, quantization error: 0.736334
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 92 ---> elapsed time:  0.654000, quantization error: 0.735955
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.033000 seconds
#  epoch: 93 ---> elapsed time:  0.545000, quantization error: 0.735566
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 94 ---> elapsed time:  0.645000, quantization error: 0.735182
#
#  find_bmu took: 0.516000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 95 ---> elapsed time:  0.766000, quantization error: 0.734815
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 96 ---> elapsed time:  0.808000, quantization error: 0.734422
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.044000 seconds
#  epoch: 97 ---> elapsed time:  0.564000, quantization error: 0.734070
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 98 ---> elapsed time:  0.549000, quantization error: 0.733716
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 99 ---> elapsed time:  0.645000, quantization error: 0.733340
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 100 ---> elapsed time:  0.634000, quantization error: 0.732958
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 101 ---> elapsed time:  0.629000, quantization error: 0.732615
#
#  find_bmu took: 0.406000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 102 ---> elapsed time:  0.660000, quantization error: 0.732289
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 103 ---> elapsed time:  0.654000, quantization error: 0.731929
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 104 ---> elapsed time:  0.660000, quantization error: 0.731552
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 105 ---> elapsed time:  0.744000, quantization error: 0.731191
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 106 ---> elapsed time:  0.543000, quantization error: 0.730835
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 107 ---> elapsed time:  0.640000, quantization error: 0.730477
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 108 ---> elapsed time:  0.528000, quantization error: 0.730119
#
#  find_bmu took: 0.310000 seconds
#  update_codebook_voronoi took: 0.040000 seconds
#  epoch: 109 ---> elapsed time:  0.550000, quantization error: 0.729715
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 110 ---> elapsed time:  0.631000, quantization error: 0.729352
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 111 ---> elapsed time:  0.631000, quantization error: 0.729001
#
#  find_bmu took: 0.609000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 112 ---> elapsed time:  0.829000, quantization error: 0.728623
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 113 ---> elapsed time:  0.641000, quantization error: 0.728248
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 114 ---> elapsed time:  0.642000, quantization error: 0.727882
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 115 ---> elapsed time:  0.643000, quantization error: 0.727505
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 116 ---> elapsed time:  0.533000, quantization error: 0.727170
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 117 ---> elapsed time:  0.623000, quantization error: 0.726837
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 118 ---> elapsed time:  0.586000, quantization error: 0.726492
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.040000 seconds
#  epoch: 119 ---> elapsed time:  0.656000, quantization error: 0.726115
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 120 ---> elapsed time:  0.526000, quantization error: 0.725724
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 121 ---> elapsed time:  0.746000, quantization error: 0.725347
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 122 ---> elapsed time:  0.630000, quantization error: 0.724980
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 123 ---> elapsed time:  0.626000, quantization error: 0.724602
#
#  find_bmu took: 0.416000 seconds
#  update_codebook_voronoi took: 0.033000 seconds
#  epoch: 124 ---> elapsed time:  0.647000, quantization error: 0.724246
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.039000 seconds
#  epoch: 125 ---> elapsed time:  0.746000, quantization error: 0.723890
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 126 ---> elapsed time:  0.535000, quantization error: 0.723519
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 127 ---> elapsed time:  0.640000, quantization error: 0.723168
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 128 ---> elapsed time:  0.657000, quantization error: 0.722814
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 129 ---> elapsed time:  0.650000, quantization error: 0.722434
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 130 ---> elapsed time:  0.623000, quantization error: 0.722064
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 131 ---> elapsed time:  0.624000, quantization error: 0.721663
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 132 ---> elapsed time:  0.618000, quantization error: 0.721261
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 133 ---> elapsed time:  0.633000, quantization error: 0.720886
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 134 ---> elapsed time:  0.630000, quantization error: 0.720508
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 135 ---> elapsed time:  0.543000, quantization error: 0.720130
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 136 ---> elapsed time:  0.640000, quantization error: 0.719720
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.040000 seconds
#  epoch: 137 ---> elapsed time:  0.650000, quantization error: 0.719354
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 138 ---> elapsed time:  0.632000, quantization error: 0.718966
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 139 ---> elapsed time:  0.638000, quantization error: 0.718606
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 140 ---> elapsed time:  0.652000, quantization error: 0.718224
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 141 ---> elapsed time:  0.759000, quantization error: 0.717858
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 142 ---> elapsed time:  0.758000, quantization error: 0.717473
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 143 ---> elapsed time:  0.638000, quantization error: 0.717042
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 144 ---> elapsed time:  0.559000, quantization error: 0.716687
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 145 ---> elapsed time:  0.525000, quantization error: 0.716333
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 146 ---> elapsed time:  0.659000, quantization error: 0.715960
#
#  find_bmu took: 0.436000 seconds
#  update_codebook_voronoi took: 0.038000 seconds
#  epoch: 147 ---> elapsed time:  0.688000, quantization error: 0.715594
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 148 ---> elapsed time:  0.782000, quantization error: 0.715252
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 149 ---> elapsed time:  0.538000, quantization error: 0.714904
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 150 ---> elapsed time:  0.736000, quantization error: 0.714551
#
#  find_bmu took: 0.608000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 151 ---> elapsed time:  0.846000, quantization error: 0.714170
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 152 ---> elapsed time:  0.543000, quantization error: 0.713825
#
#  find_bmu took: 0.522000 seconds
#  update_codebook_voronoi took: 0.045000 seconds
#  epoch: 153 ---> elapsed time:  0.766000, quantization error: 0.713434
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 154 ---> elapsed time:  0.533000, quantization error: 0.712956
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 155 ---> elapsed time:  0.639000, quantization error: 0.712601
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 156 ---> elapsed time:  0.534000, quantization error: 0.712207
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 157 ---> elapsed time:  0.545000, quantization error: 0.711818
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 158 ---> elapsed time:  0.643000, quantization error: 0.711451
#
#  find_bmu took: 0.410000 seconds
#  update_codebook_voronoi took: 0.038000 seconds
#  epoch: 159 ---> elapsed time:  0.751000, quantization error: 0.711097
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 160 ---> elapsed time:  0.637000, quantization error: 0.710738
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 161 ---> elapsed time:  0.529000, quantization error: 0.710385
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 162 ---> elapsed time:  0.621000, quantization error: 0.710033
#
#  find_bmu took: 0.208000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 163 ---> elapsed time:  0.551000, quantization error: 0.709588
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 164 ---> elapsed time:  0.624000, quantization error: 0.709218
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.039000 seconds
#  epoch: 165 ---> elapsed time:  0.558000, quantization error: 0.708833
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 166 ---> elapsed time:  0.539000, quantization error: 0.708466
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 167 ---> elapsed time:  0.647000, quantization error: 0.708092
#
#  find_bmu took: 0.305000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 168 ---> elapsed time:  0.522000, quantization error: 0.707693
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 169 ---> elapsed time:  0.518000, quantization error: 0.707313
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.040000 seconds
#  epoch: 170 ---> elapsed time:  0.679000, quantization error: 0.706904
#
#  find_bmu took: 0.421000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 171 ---> elapsed time:  0.642000, quantization error: 0.706514
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.042000 seconds
#  epoch: 172 ---> elapsed time:  0.650000, quantization error: 0.706135
#
#  find_bmu took: 0.407000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 173 ---> elapsed time:  0.623000, quantization error: 0.705731
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 174 ---> elapsed time:  0.631000, quantization error: 0.705359
#
#  find_bmu took: 0.410000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 175 ---> elapsed time:  0.628000, quantization error: 0.705006
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 176 ---> elapsed time:  0.537000, quantization error: 0.704616
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 177 ---> elapsed time:  0.536000, quantization error: 0.704250
#
#  find_bmu took: 0.620000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 178 ---> elapsed time:  0.922000, quantization error: 0.703895
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 179 ---> elapsed time:  0.775000, quantization error: 0.703549
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 180 ---> elapsed time:  0.642000, quantization error: 0.703174
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 181 ---> elapsed time:  0.637000, quantization error: 0.702807
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 182 ---> elapsed time:  0.630000, quantization error: 0.702446
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 183 ---> elapsed time:  0.640000, quantization error: 0.702089
#
#  find_bmu took: 0.410000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 184 ---> elapsed time:  0.640000, quantization error: 0.701701
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 185 ---> elapsed time:  0.542000, quantization error: 0.701334
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 186 ---> elapsed time:  0.545000, quantization error: 0.700990
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 187 ---> elapsed time:  0.560000, quantization error: 0.700639
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 188 ---> elapsed time:  0.620000, quantization error: 0.700287
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 189 ---> elapsed time:  0.560000, quantization error: 0.699919
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 190 ---> elapsed time:  0.628000, quantization error: 0.699529
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 191 ---> elapsed time:  0.634000, quantization error: 0.699168
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 192 ---> elapsed time:  0.626000, quantization error: 0.698798
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 193 ---> elapsed time:  0.623000, quantization error: 0.698423
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 194 ---> elapsed time:  0.718000, quantization error: 0.698008
#
#  find_bmu took: 0.310000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 195 ---> elapsed time:  0.550000, quantization error: 0.697656
#
#  find_bmu took: 0.406000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 196 ---> elapsed time:  0.630000, quantization error: 0.697304
#
#  find_bmu took: 0.411000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 197 ---> elapsed time:  0.659000, quantization error: 0.696951
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 198 ---> elapsed time:  0.625000, quantization error: 0.696601
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 199 ---> elapsed time:  0.521000, quantization error: 0.696253
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 200 ---> elapsed time:  0.546000, quantization error: 0.695904
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 201 ---> elapsed time:  0.631000, quantization error: 0.695544
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 202 ---> elapsed time:  0.544000, quantization error: 0.695191
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 203 ---> elapsed time:  0.632000, quantization error: 0.694851
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 204 ---> elapsed time:  0.562000, quantization error: 0.694444
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 205 ---> elapsed time:  0.559000, quantization error: 0.694079
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 206 ---> elapsed time:  0.632000, quantization error: 0.693735
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.038000 seconds
#  epoch: 207 ---> elapsed time:  0.653000, quantization error: 0.693381
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 208 ---> elapsed time:  0.643000, quantization error: 0.693000
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 209 ---> elapsed time:  0.565000, quantization error: 0.692618
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 210 ---> elapsed time:  0.646000, quantization error: 0.692257
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 211 ---> elapsed time:  0.546000, quantization error: 0.691893
#
#  find_bmu took: 0.406000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 212 ---> elapsed time:  0.626000, quantization error: 0.691497
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 213 ---> elapsed time:  0.527000, quantization error: 0.691134
#  find_bmu took: 0.411000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 214 ---> elapsed time:  0.638000, quantization error: 0.690785
#
#  find_bmu took: 0.311000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 215 ---> elapsed time:  0.556000, quantization error: 0.690437
#
#  find_bmu took: 0.420000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 216 ---> elapsed time:  0.660000, quantization error: 0.690103
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 217 ---> elapsed time:  0.649000, quantization error: 0.689777
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 218 ---> elapsed time:  0.645000, quantization error: 0.689440
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 219 ---> elapsed time:  0.619000, quantization error: 0.689084
#
#  find_bmu took: 0.610000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 220 ---> elapsed time:  0.861000, quantization error: 0.688751
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 221 ---> elapsed time:  0.799000, quantization error: 0.688404
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 222 ---> elapsed time:  0.530000, quantization error: 0.688070
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 223 ---> elapsed time:  0.642000, quantization error: 0.687756
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 224 ---> elapsed time:  0.658000, quantization error: 0.687401
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.044000 seconds
#  epoch: 225 ---> elapsed time:  0.642000, quantization error: 0.687040
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 226 ---> elapsed time:  0.621000, quantization error: 0.686680
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 227 ---> elapsed time:  0.637000, quantization error: 0.686328
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.042000 seconds
#  epoch: 228 ---> elapsed time:  0.685000, quantization error: 0.685939
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 229 ---> elapsed time:  0.636000, quantization error: 0.685546
#
#  find_bmu took: 0.410000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 230 ---> elapsed time:  0.627000, quantization error: 0.685154
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 231 ---> elapsed time:  0.545000, quantization error: 0.684780
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 232 ---> elapsed time:  0.657000, quantization error: 0.684416
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 233 ---> elapsed time:  0.617000, quantization error: 0.684074
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 234 ---> elapsed time:  0.742000, quantization error: 0.683707
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 235 ---> elapsed time:  0.646000, quantization error: 0.683355
#
#  find_bmu took: 0.415000 seconds
#  update_codebook_voronoi took: 0.033000 seconds
#  epoch: 236 ---> elapsed time:  0.656000, quantization error: 0.682996
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 237 ---> elapsed time:  0.722000, quantization error: 0.682642
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 238 ---> elapsed time:  0.763000, quantization error: 0.682297
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.045000 seconds
#  epoch: 239 ---> elapsed time:  0.640000, quantization error: 0.681964
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 240 ---> elapsed time:  0.538000, quantization error: 0.681602
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 241 ---> elapsed time:  0.553000, quantization error: 0.681259
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 242 ---> elapsed time:  0.541000, quantization error: 0.680840
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 243 ---> elapsed time:  0.643000, quantization error: 0.680459
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 244 ---> elapsed time:  0.636000, quantization error: 0.680055
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 245 ---> elapsed time:  0.539000, quantization error: 0.679725
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 246 ---> elapsed time:  0.641000, quantization error: 0.679321
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 247 ---> elapsed time:  0.541000, quantization error: 0.678946
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 248 ---> elapsed time:  0.542000, quantization error: 0.678590
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 249 ---> elapsed time:  0.644000, quantization error: 0.678231
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 250 ---> elapsed time:  0.646000, quantization error: 0.677881
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 251 ---> elapsed time:  0.636000, quantization error: 0.677498
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.042000 seconds
#  epoch: 252 ---> elapsed time:  0.559000, quantization error: 0.677119
#
#  find_bmu took: 0.609000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 253 ---> elapsed time:  0.885000, quantization error: 0.676770
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 254 ---> elapsed time:  0.690000, quantization error: 0.676404
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 255 ---> elapsed time:  0.574000, quantization error: 0.676026
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 256 ---> elapsed time:  0.723000, quantization error: 0.675667
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 257 ---> elapsed time:  0.632000, quantization error: 0.675291
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.038000 seconds
#  epoch: 258 ---> elapsed time:  0.640000, quantization error: 0.674884
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 259 ---> elapsed time:  0.626000, quantization error: 0.674489
#
#  find_bmu took: 0.410000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 260 ---> elapsed time:  0.637000, quantization error: 0.674123
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.041000 seconds
#  epoch: 261 ---> elapsed time:  0.664000, quantization error: 0.673769
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.015000 seconds
#  epoch: 262 ---> elapsed time:  0.643000, quantization error: 0.673410
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 263 ---> elapsed time:  0.638000, quantization error: 0.673074
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 264 ---> elapsed time:  0.654000, quantization error: 0.672712
#
#  find_bmu took: 0.609000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 265 ---> elapsed time:  0.848000, quantization error: 0.672319
#
#  find_bmu took: 0.507000 seconds
#  update_codebook_voronoi took: 0.033000 seconds
#  epoch: 266 ---> elapsed time:  0.854000, quantization error: 0.671967
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 267 ---> elapsed time:  0.636000, quantization error: 0.671600
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 268 ---> elapsed time:  0.734000, quantization error: 0.671267
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.042000 seconds
#  epoch: 269 ---> elapsed time:  0.647000, quantization error: 0.670894
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.033000 seconds
#  epoch: 270 ---> elapsed time:  0.656000, quantization error: 0.670540
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 271 ---> elapsed time:  0.561000, quantization error: 0.670178
#
#  find_bmu took: 0.415000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 272 ---> elapsed time:  0.643000, quantization error: 0.669832
#
#  find_bmu took: 0.406000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 273 ---> elapsed time:  0.629000, quantization error: 0.669483
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.042000 seconds
#  epoch: 274 ---> elapsed time:  0.634000, quantization error: 0.669141
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 275 ---> elapsed time:  0.648000, quantization error: 0.668784
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 276 ---> elapsed time:  0.635000, quantization error: 0.668449
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.033000 seconds
#  epoch: 277 ---> elapsed time:  0.670000, quantization error: 0.668087
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 278 ---> elapsed time:  0.625000, quantization error: 0.667749
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 279 ---> elapsed time:  0.635000, quantization error: 0.667408
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 280 ---> elapsed time:  0.634000, quantization error: 0.667055
#
#  find_bmu took: 0.416000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 281 ---> elapsed time:  0.647000, quantization error: 0.666695
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 282 ---> elapsed time:  0.748000, quantization error: 0.666345
#
#  find_bmu took: 0.437000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 283 ---> elapsed time:  0.662000, quantization error: 0.665996
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 284 ---> elapsed time:  0.627000, quantization error: 0.665626
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 285 ---> elapsed time:  0.636000, quantization error: 0.665295
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 286 ---> elapsed time:  0.630000, quantization error: 0.664983
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 287 ---> elapsed time:  0.647000, quantization error: 0.664657
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.040000 seconds
#  epoch: 288 ---> elapsed time:  0.650000, quantization error: 0.664305
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 289 ---> elapsed time:  0.631000, quantization error: 0.663943
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 290 ---> elapsed time:  0.575000, quantization error: 0.663588
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.041000 seconds
#  epoch: 291 ---> elapsed time:  0.566000, quantization error: 0.663217
#
#  find_bmu took: 0.612000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 292 ---> elapsed time:  0.905000, quantization error: 0.662882
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 293 ---> elapsed time:  0.654000, quantization error: 0.662536
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 294 ---> elapsed time:  0.639000, quantization error: 0.662198
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 295 ---> elapsed time:  0.627000, quantization error: 0.661857
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 296 ---> elapsed time:  0.643000, quantization error: 0.661514
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 297 ---> elapsed time:  0.529000, quantization error: 0.661178
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 298 ---> elapsed time:  0.530000, quantization error: 0.660747
#
#  find_bmu took: 0.305000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 299 ---> elapsed time:  0.518000, quantization error: 0.660299
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 300 ---> elapsed time:  0.544000, quantization error: 0.659933
#
#  find_bmu took: 0.210000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 301 ---> elapsed time:  0.435000, quantization error: 0.659592
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 302 ---> elapsed time:  0.633000, quantization error: 0.659234
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 303 ---> elapsed time:  0.649000, quantization error: 0.658927
#
#  find_bmu took: 0.413000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 304 ---> elapsed time:  0.652000, quantization error: 0.658592
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.052000 seconds
#  epoch: 305 ---> elapsed time:  0.567000, quantization error: 0.658213
#
#  find_bmu took: 0.614000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 306 ---> elapsed time:  0.908000, quantization error: 0.657856
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 307 ---> elapsed time:  0.814000, quantization error: 0.657513
#
#  find_bmu took: 0.316000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 308 ---> elapsed time:  0.541000, quantization error: 0.657153
#
#  find_bmu took: 0.421000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 309 ---> elapsed time:  0.662000, quantization error: 0.656798
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 310 ---> elapsed time:  0.658000, quantization error: 0.656463
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 311 ---> elapsed time:  0.629000, quantization error: 0.656115
#
#  find_bmu took: 0.408000 seconds
# ...
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 340 ---> elapsed time:  0.540000, quantization error: 0.645384
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 341 ---> elapsed time:  0.630000, quantization error: 0.644962
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 342 ---> elapsed time:  0.644000, quantization error: 0.644574
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 343 ---> elapsed time:  0.523000, quantization error: 0.644180
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 344 ---> elapsed time:  0.532000, quantization error: 0.643846
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 345 ---> elapsed time:  0.631000, quantization error: 0.643485
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 346 ---> elapsed time:  0.667000, quantization error: 0.643136
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 347 ---> elapsed time:  0.544000, quantization error: 0.642759
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 348 ---> elapsed time:  0.532000, quantization error: 0.642370
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 349 ---> elapsed time:  0.741000, quantization error: 0.642025
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 350 ---> elapsed time:  0.639000, quantization error: 0.641676
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 351 ---> elapsed time:  0.537000, quantization error: 0.641319
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 352 ---> elapsed time:  0.536000, quantization error: 0.640857
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 353 ---> elapsed time:  0.645000, quantization error: 0.640433
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 354 ---> elapsed time:  0.536000, quantization error: 0.640152
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 355 ---> elapsed time:  0.551000, quantization error: 0.639812
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 356 ---> elapsed time:  0.652000, quantization error: 0.639510
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.034000 seconds
#  epoch: 357 ---> elapsed time:  0.556000, quantization error: 0.639185
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 358 ---> elapsed time:  0.638000, quantization error: 0.638829
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.040000 seconds
#  epoch: 359 ---> elapsed time:  0.652000, quantization error: 0.638472
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 360 ---> elapsed time:  0.652000, quantization error: 0.638116
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 361 ---> elapsed time:  0.633000, quantization error: 0.637763
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 362 ---> elapsed time:  0.542000, quantization error: 0.637416
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 363 ---> elapsed time:  0.535000, quantization error: 0.637071
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 364 ---> elapsed time:  0.647000, quantization error: 0.636702
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 365 ---> elapsed time:  0.739000, quantization error: 0.636356
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 366 ---> elapsed time:  0.646000, quantization error: 0.636028
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 367 ---> elapsed time:  0.642000, quantization error: 0.635700
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 368 ---> elapsed time:  0.554000, quantization error: 0.635394
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 369 ---> elapsed time:  0.555000, quantization error: 0.635057
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 370 ---> elapsed time:  0.650000, quantization error: 0.634694
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.032000 seconds
#  epoch: 371 ---> elapsed time:  0.632000, quantization error: 0.634306
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 372 ---> elapsed time:  0.816000, quantization error: 0.633961
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 373 ---> elapsed time:  0.637000, quantization error: 0.633591
#
#  find_bmu took: 0.508000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 374 ---> elapsed time:  0.758000, quantization error: 0.633239
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 375 ---> elapsed time:  0.546000, quantization error: 0.632866
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.022000 seconds
#  epoch: 376 ---> elapsed time:  0.633000, quantization error: 0.632527
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.030000 seconds
#  epoch: 377 ---> elapsed time:  0.660000, quantization error: 0.632213
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 378 ---> elapsed time:  0.544000, quantization error: 0.631913
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 379 ---> elapsed time:  0.517000, quantization error: 0.631581
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.042000 seconds
#  epoch: 380 ---> elapsed time:  0.658000, quantization error: 0.631249
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 381 ---> elapsed time:  0.618000, quantization error: 0.630903
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 382 ---> elapsed time:  0.547000, quantization error: 0.630552
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 383 ---> elapsed time:  0.631000, quantization error: 0.630206
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 384 ---> elapsed time:  0.526000, quantization error: 0.629842
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.055000 seconds
#  epoch: 385 ---> elapsed time:  0.560000, quantization error: 0.629495
#
#  find_bmu took: 0.709000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 386 ---> elapsed time:  1.008000, quantization error: 0.629158
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 387 ---> elapsed time:  0.701000, quantization error: 0.628829
#
#  find_bmu took: 0.411000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 388 ---> elapsed time:  0.627000, quantization error: 0.628493
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 389 ---> elapsed time:  0.550000, quantization error: 0.628099
#
#  find_bmu took: 0.209000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 390 ---> elapsed time:  0.452000, quantization error: 0.627735
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.047000 seconds
#  epoch: 391 ---> elapsed time:  0.652000, quantization error: 0.627399
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 392 ---> elapsed time:  0.623000, quantization error: 0.627085
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.043000 seconds
#  epoch: 393 ---> elapsed time:  0.644000, quantization error: 0.626748
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.023000 seconds
#  epoch: 394 ---> elapsed time:  0.620000, quantization error: 0.626444
#
#  find_bmu took: 0.515000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 395 ---> elapsed time:  0.754000, quantization error: 0.626122
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 396 ---> elapsed time:  0.571000, quantization error: 0.625681
#
#  find_bmu took: 0.518000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 397 ---> elapsed time:  0.808000, quantization error: 0.625311
#
#  find_bmu took: 0.513000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 398 ---> elapsed time:  0.777000, quantization error: 0.624948
#
#  find_bmu took: 0.410000 seconds
#  update_codebook_voronoi took: 0.026000 seconds
#  epoch: 399 ---> elapsed time:  0.709000, quantization error: 0.624572
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.021000 seconds
#  epoch: 400 ---> elapsed time:  0.537000, quantization error: 0.624142
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.017000 seconds
#  epoch: 401 ---> elapsed time:  0.637000, quantization error: 0.623769
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.024000 seconds
#  epoch: 402 ---> elapsed time:  0.642000, quantization error: 0.623325
#
#  find_bmu took: 0.309000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 403 ---> elapsed time:  0.537000, quantization error: 0.622842
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 404 ---> elapsed time:  0.640000, quantization error: 0.622401
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 405 ---> elapsed time:  0.633000, quantization error: 0.622039
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.016000 seconds
#  epoch: 406 ---> elapsed time:  0.537000, quantization error: 0.621640
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.025000 seconds
#  epoch: 407 ---> elapsed time:  0.539000, quantization error: 0.621257
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 408 ---> elapsed time:  0.653000, quantization error: 0.620868
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 409 ---> elapsed time:  0.634000, quantization error: 0.620522
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 410 ---> elapsed time:  0.663000, quantization error: 0.620172
#
#  find_bmu took: 0.411000 seconds
#  update_codebook_voronoi took: 0.018000 seconds
#  epoch: 411 ---> elapsed time:  0.620000, quantization error: 0.619828
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.037000 seconds
#  epoch: 412 ---> elapsed time:  0.650000, quantization error: 0.619495
#
#  find_bmu took: 0.511000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 413 ---> elapsed time:  0.744000, quantization error: 0.619131
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.028000 seconds
#  epoch: 414 ---> elapsed time:  0.681000, quantization error: 0.618770
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 415 ---> elapsed time:  0.741000, quantization error: 0.618424
#
#  find_bmu took: 0.308000 seconds
#  update_codebook_voronoi took: 0.027000 seconds
#  epoch: 416 ---> elapsed time:  0.535000, quantization error: 0.618076
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.036000 seconds
#  epoch: 417 ---> elapsed time:  0.656000, quantization error: 0.617710
#
#  find_bmu took: 0.710000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 418 ---> elapsed time:  0.974000, quantization error: 0.617354
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.033000 seconds
#  epoch: 419 ---> elapsed time:  0.665000, quantization error: 0.617010
#
#  find_bmu took: 0.713000 seconds
#  update_codebook_voronoi took: 0.029000 seconds
#  epoch: 420 ---> elapsed time:  0.944000, quantization error: 0.616648
#
#  find_bmu took: 0.509000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 421 ---> elapsed time:  0.806000, quantization error: 0.616258
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.031000 seconds
#  epoch: 422 ---> elapsed time:  0.644000, quantization error: 0.615954
#
#  find_bmu took: 0.409000 seconds
#  update_codebook_voronoi took: 0.019000 seconds
#  epoch: 423 ---> elapsed time:  0.633000, quantization error: 0.615615
#
#  find_bmu took: 0.411000 seconds
#  update_codebook_voronoi took: 0.035000 seconds
#  epoch: 424 ---> elapsed time:  0.661000, quantization error: 0.615198
#
#  find_bmu took: 0.408000 seconds
#  update_codebook_voronoi took: 0.020000 seconds
#  epoch: 425 ---> elapsed time:  0.650000, quantization error: 0.614816
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-170-89c4ed3ad0e6> in <module>
#       2 mapsize = [50,50]
#       3 som = sompy.SOMFactory.build(data, mapsize, mask=None, mapshape='planar', lattice="rect", normalization='var', initialization='pca', neighborhood='gaussian', training='batch', name='sompy')
# ----> 4 som.train(n_job=4, verbose='debug', train_rough_len=1000)
#
# ~/.local/lib/python3.6/site-packages/sompy/decorators.py in wrapped_f(*args, **kwargs)
#       9         def wrapped_f(*args, **kwargs):
#      10             t0 = time()
# ---> 11             result = f(*args, **kwargs)
#      12             ts = round(time() - t0, 3)
#      13
#
# ~/.local/lib/python3.6/site-packages/sompy/sompy.py in train(self, n_job, shared_memory, verbose, train_rough_len, train_rough_radiusin, train_rough_radiusfin, train_finetune_len, train_finetune_radiusin, train_finetune_radiusfin, train_len_factor, maxtrainlen)
#     250
#     251         self.rough_train(njob=n_job, shared_memory=shared_memory, trainlen=train_rough_len,
# --> 252                          radiusin=train_rough_radiusin, radiusfin=train_rough_radiusfin,trainlen_factor=train_len_factor,maxtrainlen=maxtrainlen)
#     253         self.finetune_train(njob=n_job, shared_memory=shared_memory, trainlen=train_finetune_len,
#     254                             radiusin=train_finetune_radiusin, radiusfin=train_finetune_radiusfin,trainlen_factor=train_len_factor,maxtrainlen=maxtrainlen)
#
# ~/.local/lib/python3.6/site-packages/sompy/sompy.py in rough_train(self, njob, shared_memory, trainlen, radiusin, radiusfin, trainlen_factor, maxtrainlen)
#     287             radiusfin = max(1, radiusin/4.) if not radiusfin else radiusfin
#     288
# --> 289         self._batchtrain(trainlen, radiusin, radiusfin, njob, shared_memory)
#     290
#     291     def finetune_train(self, njob=1, shared_memory=False, trainlen=None, radiusin=None, radiusfin=None,trainlen_factor=1,maxtrainlen=np.Inf):
#
# ~/.local/lib/python3.6/site-packages/sompy/sompy.py in _batchtrain(self, trainlen, radiusin, radiusfin, njob, shared_memory)
#     341             t1 = time()
#     342             neighborhood = self.neighborhood.calculate(
# --> 343                 self._distance_matrix, radius[i], self.codebook.nnodes)
#     344             bmu = self.find_bmu(data, njb=njob)
#     345             self.codebook.matrix = self.update_codebook_voronoi(data, bmu,
#
# ~/.local/lib/python3.6/site-packages/sompy/neighborhood.py in calculate(distance_matrix, radius, dim)
#      25     @staticmethod
#      26     def calculate(distance_matrix, radius, dim):
# ---> 27         return np.exp(-1.0*distance_matrix/(2.0*radius**2)).reshape(dim, dim)
#      28
#      29     def __call__(self, *args, **kwargs):
#
# KeyboardInterrupt:

# %%
# Visualization Plots
som.cluster(2)
vis  = sompy.mapview.View2DPacked(5, 5, 'Cluster',text_size=12)  
kmeans_labels = cluster(som, n_clusters=2)
som.cluster_labels = kmeans_labels.labels_

vis.show(som, what='cluster')

from sompy.visualization.bmuhits import BmuHitsView
#sm.codebook.lattice="rect"
vhts  = BmuHitsView(12,12,"Hits Map",text_size=7)
vhts.show(som, anotate=True, onlyzeros=False, labelsize=7, cmap="autumn", logaritmic=False)
plt.show()
# Out:
# /home/mariana/.local/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x7ff4c8f0c6d8>
# Using auto colorbar locator on colorbar
# locator: <matplotlib.colorbar._ColorbarAutoLocator object at 0x7ff4c8f0c6d8>
# Setting pcolormesh
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos
# update_title_pos

# %%
#Generate maps
som.component_names = ["01", "02", "03", "04", "05", "06"]
v  = sompy.mapview.View2DPacked(10, 10, 'Pacient 01 - Velocity 0.8m/s',text_size=9)
v.show(som, what='codebook', which_dim='all', cmap='jet', col_sz=5) #which_dim='all' default
# Out:
# ---------------------------------------------------------------------------
# ComponentNamesError                       Traceback (most recent call last)
# <ipython-input-169-d2297531bc92> in <module>
#       1 #Generate maps
# ----> 2 som.component_names = ["01", "02", "03", "04", "05", "06"]
#       3 v  = sompy.mapview.View2DPacked(10, 10, 'Pacient 01 - Velocity 0.8m/s',text_size=9)
#       4 v.show(som, what='codebook', which_dim='all', cmap='jet', col_sz=5) #which_dim='all' default
#
# ~/.local/lib/python3.6/site-packages/sompy/sompy.py in component_names(self, compnames)
#     158             self._component_names = np.asarray(compnames)[np.newaxis, :]
#     159         else:
# --> 160             raise ComponentNamesError('Component names should have the same '
#     161                                       'size as the data dimension/features')
#     162
#
# ComponentNamesError: Component names should have the same size as the data dimension/features

# %%
["aa", "bb"] + ["cc"]
# Out:
# ['aa', 'bb', 'cc']
